# %% [markdown]
# # Lux
#
# Python Library for Intelligent Visual Discovery

# %%
# !pip install lux
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/127.0 kB ? eta -:--:--
#      --------- ------------------------------ 30.7/127.0 kB ? eta -:--:--
#      --------- ------------------------------ 30.7/127.0 kB ? eta -:--:--
#      --------- ------------------------------ 30.7/127.0 kB ? eta -:--:--
#      ----------- ------------------------- 41.0/127.0 kB 196.9 kB/s eta 0:00:01
#      ----------- ------------------------- 41.0/127.0 kB 196.9 kB/s eta 0:00:01
#      ----------------- ------------------- 61.4/127.0 kB 193.2 kB/s eta 0:00:01
#      ----------------------- ------------- 81.9/127.0 kB 209.0 kB/s eta 0:00:01
#      ----------------------- ------------- 81.9/127.0 kB 209.0 kB/s eta 0:00:01
#      -------------------------- ---------- 92.2/127.0 kB 194.6 kB/s eta 0:00:01
#      ------------------------------- ---- 112.6/127.0 kB 218.8 kB/s eta 0:00:01
# ...

# %%
import lux
import pandas as pd
